# %% [markdown]
# ### Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto- Part 2 Solution

# %%
import numpy as np
import pandas as pd

# !pip install geocoder
print('  >>>>>   Installing Geocoder........ Please wait')

print('   :::::  COMPLETED  :::::  ')
# Out:
# Requirement already satisfied: geocoder in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: future in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: click in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (7.0)
# Requirement already satisfied: ratelim in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2019.11.28)
# Requirement already satisfied: decorator in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.2)
#   >>>>>   Installing Geocoder........ Please wait
#    :::::  COMPLETED  :::::

# %%
df = pd.read_csv('toronto1.csv')
print(df)
# Out:
#     Unnamed: 0 Postcode           Borough  \
# 0            0      M8W         Etobicoke
# 1            1      M5L  Downtown Toronto
# 2            2      M2R        North York
# 3            3      M8V         Etobicoke
# 4            4      M1R       Scarborough
# 5            5      M4B         East York
# 6            6      M5P   Central Toronto
# 7            7      M4H         East York
# 8            8      M3A        North York
# 9            9      M6A        North York
# 10          10      M6H      West Toronto
# 11          11      M3K        North York
# 12          12      M1P       Scarborough
# 13          13      M9M        North York
# 14          14      M4K      East Toronto
# 15          15      M4V   Central Toronto
# 16          16      M9B         Etobicoke
# 17          17      M8Z         Etobicoke
# 18          18      M5C  Downtown Toronto
# 19          19      M1C       Scarborough
# 20          20      M6J      West Toronto
# 21          21      M5E  Downtown Toronto
# 22          22      M1T       Scarborough
# 23          23      M4Y  Downtown Toronto
# 24          24      M5S  Downtown Toronto
# 25          25      M2H        North York
# 26          26      M1L       Scarborough
# 27          27      M5T  Downtown Toronto
# 28          28      M6K      West Toronto
# 29          29      M5K  Downtown Toronto
# ..         ...      ...               ...
# 47          47      M9N              York
# 48          48      M6R      West Toronto
# 49          49      M8X         Etobicoke
# 50          50      M2K        North York
# 51          51      M6P      West Toronto
# 52          52      M6L        North York
# 53          53      M5J  Downtown Toronto
# 54          54      M1B       Scarborough
# 55          55      M4C         East York
# 56          56      M5A  Downtown Toronto
# 57          57      M1M       Scarborough
# 58          58      M6S      West Toronto
# 59          59      M4W  Downtown Toronto
# 60          60      M2J        North York
# 61          61      M1G       Scarborough
# 62          62      M4G         East York
# 63          63      M1J       Scarborough
# 64          64      M9L        North York
# 65          65      M3L        North York
# 66          66      M1X       Scarborough
# 67          67      M1S       Scarborough
# 68          68      M2M        North York
# 69          69      M9C         Etobicoke
# 70          70      M1E       Scarborough
# 71          71      M4A        North York
# 72          72      M7A  Downtown Toronto
# 73          73      M9V         Etobicoke
# 74          74      M4J         East York
# 75          75      M4E      East Toronto
# 76          76      M1V       Scarborough
#
#                                         Neighbourhood
# 0                              Alderwood, Long Branch
# 1                                      Commerce Court
# 2                                     Willowdale West
# 3                                         New Toronto
# 4                                   Maryvale, Wexford
# 5                     Woodbine Gardens, Parkview Hill
# 6                                   Forest Hill North
# 7                                    Thorncliffe Park
# 8                                           Parkwoods
# 9                    Lawrence Heights, Lawrence Manor
# 10                                 Dovercourt Village
# 11                                        CFB Toronto
# 12  Dorset Park, Scarborough Town Centre, Wexford ...
# 13                                   Emery, Humberlea
# 14                                          Riverdale
# 15                   Deer Park, Rathnelly, South Hill
# 16       Islington, Princess Gardens, West Deane Park
# 17                      Mimico NW, The Queensway West
# 18                                     St. James Town
# 19             Highland Creek, Rouge Hill, Port Union
# 20                           Little Portugal, Trinity
# 21                                        Berczy Park
# 22                                      Tam O'Shanter
# 23                               Church and Wellesley
# 24                              University of Toronto
# 25                                  Hillcrest Village
# 26                    Clairlea, Golden Mile, Oakridge
# 27          Chinatown, Grange Park, Kensington Market
# 28                 Exhibition Place, Parkdale Village
# 29           Design Exchange, Toronto Dominion Centre
# ..                                                ...
# 47                                             Weston
# 48                             Parkdale, Roncesvalles
# 49                                       The Kingsway
# 50                                    Bayview Village
# 51                                          High Park
# 52                                          Downsview
# 53                     Toronto Islands, Union Station
# 54                                     Rouge, Malvern
# 55                                   Woodbine Heights
# 56                                       Harbourfront
# 57                              Cliffcrest, Cliffside
# 58                                 Runnymede, Swansea
# 59                                           Rosedale
# 60                                         Henry Farm
# 61                                             Woburn
# 62                                            Leaside
# 63                                Scarborough Village
# 64                                      Humber Summit
# 65                                     Downsview West
# 66                                        Upper Rouge
# 67                                          Agincourt
# 68                            Newtonbrook, Willowdale
# 69                                      Markland Wood
# 70                             Morningside, West Hill
# 71                                   Victoria Village
# 72                                       Queen's Park
# 73  Beaumond Heights, Jamestown, Mount Olive, Silv...
# 74                                       East Toronto
# 75                                        The Beaches
# 76                          Agincourt North, Milliken
#
# [77 rows x 4 columns]

# %%
coordinates_df = pd.read_csv('http://cocl.us/Geospatial_data') 
coordinates_df.shape
coordinates_df.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %%
coordinates_df = df.join(coordinates_df.set_index('Postal Code'), on='Postcode')
coordinates_df.to_csv('coordinates.csv')
coordinates_df.head(20)
# Out:
#     Unnamed: 0 Postcode           Borough  \
# 0            0      M8W         Etobicoke
# 1            1      M5L  Downtown Toronto
# 2            2      M2R        North York
# 3            3      M8V         Etobicoke
# 4            4      M1R       Scarborough
# 5            5      M4B         East York
# 6            6      M5P   Central Toronto
# 7            7      M4H         East York
# 8            8      M3A        North York
# 9            9      M6A        North York
# 10          10      M6H      West Toronto
# 11          11      M3K        North York
# 12          12      M1P       Scarborough
# 13          13      M9M        North York
# 14          14      M4K      East Toronto
# 15          15      M4V   Central Toronto
# 16          16      M9B         Etobicoke
# 17          17      M8Z         Etobicoke
# 18          18      M5C  Downtown Toronto
# 19          19      M1C       Scarborough
#
#                                         Neighbourhood   Latitude  Longitude
# 0                              Alderwood, Long Branch  43.602414 -79.543484
# 1                                      Commerce Court  43.648198 -79.379817
# 2                                     Willowdale West  43.782736 -79.442259
# 3                                         New Toronto  43.605647 -79.501321
# 4                                   Maryvale, Wexford  43.750072 -79.295849
# 5                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 6                                   Forest Hill North  43.696948 -79.411307
# 7                                    Thorncliffe Park  43.705369 -79.349372
# 8                                           Parkwoods  43.753259 -79.329656
# 9                    Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 10                                 Dovercourt Village  43.669005 -79.442259
# 11                                        CFB Toronto  43.737473 -79.464763
# 12  Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 13                                   Emery, Humberlea  43.724766 -79.532242
# 14                                          Riverdale  43.679557 -79.352188
# 15                   Deer Park, Rathnelly, South Hill  43.686412 -79.400049
# 16       Islington, Princess Gardens, West Deane Park  43.650943 -79.554724
# 17                      Mimico NW, The Queensway West  43.628841 -79.520999
# 18                                     St. James Town  43.651494 -79.375418
# 19             Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
